# %%
import pandas as pd

# %%
# Usamos o "../" para pular uma pasta, se usado 2x, pulará duas pastas. Exp: "../../"
df_bronze = pd.read_csv("../arquivo_base/base_prf.csv", sep=";", encoding="utf-8", low_memory=False)
df_bronze.to_csv("../data/1-bronze/bronze_acidentes.csv", index=False)
print(df_bronze.head())
